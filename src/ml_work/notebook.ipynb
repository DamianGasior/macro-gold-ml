# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#          length is : 913
#         confusion matrix       [[TP - 320 ; FP - 166]
#                                [FN - 283 ;  TN - 144]]
#
#      accuracy_score is : 0.5082146768893757 , how many of the TP and FN were correct
#      for prceision 53 % of being down were correction,  46% up were fine
#
#      Recall - 66% of predictions for true DOWN were correct, only 34% predictions for true ups ,were correct.
#
#      ROC AUC 0.4901311668160484
